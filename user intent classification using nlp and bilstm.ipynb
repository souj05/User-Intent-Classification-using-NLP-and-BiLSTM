# %% [markdown]
# # User Intent Classification using NLP + BiLSTM
# ### CLINC150 Dataset — 151 Classes, 23,700 Samples

# %% [markdown]
# ```
#
# ##   1: Install & Import Libraries

# %%
# !pip install tensorflow scikit-learn pandas numpy matplotlib seaborn -q

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pickle, json, urllib.request
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SpatialDropout1D, Bidirectional, LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

print('TensorFlow:', tf.__version__)
print('GPU:', tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.20.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ##  2: Load CLINC150 Dataset
# Load CLINC150 dataset with 23,700 text samples and 151 intent labels.

# %%
# Download CLINC150 dataset from GitHub
url = 'https://raw.githubusercontent.com/clinc/oos-eval/master/data/data_full.json'
urllib.request.urlretrieve(url, 'clinc150.json')

with open('clinc150.json') as f:
    data = json.load(f)

# Combine in-scope + out-of-scope splits
train_data = data['train'] + data['oos_train']
val_data   = data['val']   + data['oos_val']
test_data  = data['test']  + data['oos_test']

df_train = pd.DataFrame(train_data, columns=['text', 'intent'])
df_val   = pd.DataFrame(val_data,   columns=['text', 'intent'])
df_test  = pd.DataFrame(test_data,  columns=['text', 'intent'])

print(f'Train: {len(df_train)} | Val: {len(df_val)} | Test: {len(df_test)}')
print(f'Total: {len(df_train)+len(df_val)+len(df_test)} samples')
print(f'Intent classes: {df_train["intent"].nunique()}')
df_train.head()
# Out:
# Train: 15100 | Val: 3100 | Test: 5500
# Total: 23700 samples
# Intent classes: 151
#                                                 text     intent
# 0  what expression would i use to say i love you ...  translate
# 1  can you tell me how to say 'i do not speak muc...  translate
# 2  what is the equivalent of, 'life is good' in f...  translate
# 3  tell me how to say, 'it is a beautiful morning...  translate
# 4  if i were mongolian, how would i say that i am...  translate

# %% [markdown]
# ## 3: Preprocessing — Tokenize + Pad + Label Encoding
# Convert text to numbers (tokenize) and make all sequences same length (padding).

# %%
# --- Label Encoding ---
le = LabelEncoder()
all_intents = pd.concat([df_train, df_val, df_test])['intent']
le.fit(all_intents)

y_train = le.transform(df_train['intent'])
y_val   = le.transform(df_val['intent'])
y_test  = le.transform(df_test['intent'])

# --- Tokenization ---
MAX_WORDS = 20000
MAX_LEN   = 30

tokenizer = Tokenizer(num_words=MAX_WORDS, oov_token='<OOV>')
tokenizer.fit_on_texts(df_train['text'])

X_train = pad_sequences(tokenizer.texts_to_sequences(df_train['text']), maxlen=MAX_LEN, padding='post')
X_val   = pad_sequences(tokenizer.texts_to_sequences(df_val['text']),   maxlen=MAX_LEN, padding='post')
X_test  = pad_sequences(tokenizer.texts_to_sequences(df_test['text']),  maxlen=MAX_LEN, padding='post')

print(f'Vocab size: {len(tokenizer.word_index)}')
print(f'X_train: {X_train.shape} | X_val: {X_val.shape} | X_test: {X_test.shape}')
print(f'Classes: {len(le.classes_)}')

# Save artifacts
with open('tokenizer.pkl', 'wb') as f: pickle.dump(tokenizer, f)
with open('label_encoder.pkl', 'wb') as f: pickle.dump(le, f)
# Out:
# Vocab size: 5351
# X_train: (15100, 30) | X_val: (3100, 30) | X_test: (5500, 30)
# Classes: 151

# %% [markdown]
# ##  4: Build BiLSTM Model
# Build BiLSTM model: reads text forward+backward to understand context better.

# %%
VOCAB_SIZE = min(MAX_WORDS, len(tokenizer.word_index) + 1)
EMBED_DIM = 100
NUM_CLASSES = len(le.classes_)

model = Sequential([
    Embedding(VOCAB_SIZE, EMBED_DIM),
    SpatialDropout1D(0.3),
    Bidirectional(LSTM(128, return_sequences=True)),
    Dropout(0.3),
    Bidirectional(LSTM(64)),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(NUM_CLASSES, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=1e-3),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout1d               │ ?                      │             0 │
# │ (SpatialDropout1D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 5: Train the Model
# Train model on data, it learns which words map to which intents over 20 rounds.

# %%
callbacks = [EarlyStopping(patience=3, restore_best_weights=True, verbose=1),ModelCheckpoint('best_model.keras', save_best_only=True, verbose=1)]

history = model.fit(X_train, y_train,validation_data=(X_val, y_val),epochs=20,batch_size=64,callbacks=callbacks)

# Plot training curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(history.history['accuracy'], label='Train')
ax1.plot(history.history['val_accuracy'], label='Validation')
ax1.set_title('Accuracy'); ax1.legend()

ax2.plot(history.history['loss'], label='Train')
ax2.plot(history.history['val_loss'], label='Validation')
ax2.set_title('Loss'); ax2.legend()

plt.tight_layout()
plt.show()

print(f'\nBest Val Accuracy: {max(history.history["val_accuracy"]):.4f}')
# Out:
# Epoch 1/20
# 234/236 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.0088 - loss: 4.9476
# Epoch 1: val_loss improved from None to 3.98676, saving model to best_model.keras
#
# Epoch 1: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 14s 22ms/step - accuracy: 0.0164 - loss: 4.7449 - val_accuracy: 0.0784 - val_loss: 3.9868
# Epoch 2/20
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0889 - loss: 3.7380
# Epoch 2: val_loss improved from 3.98676 to 2.54095, saving model to best_model.keras
#
# Epoch 2: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.1363 - loss: 3.3833 - val_accuracy: 0.3468 - val_loss: 2.5409
# Epoch 3/20
# 235/236 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3182 - loss: 2.3595
# Epoch 3: val_loss improved from 2.54095 to 1.63274, saving model to best_model.keras
#
# Epoch 3: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.3701 - loss: 2.1624 - val_accuracy: 0.5877 - val_loss: 1.6327
# Epoch 4/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5398 - loss: 1.5126
# Epoch 4: val_loss improved from 1.63274 to 1.20790, saving model to best_model.keras
#
# Epoch 4: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.5755 - loss: 1.4055 - val_accuracy: 0.6942 - val_loss: 1.2079
# Epoch 5/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.7006 - loss: 1.0175
# Epoch 5: val_loss improved from 1.20790 to 1.03055, saving model to best_model.keras
#
# Epoch 5: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.7105 - loss: 0.9799 - val_accuracy: 0.7542 - val_loss: 1.0305
# Epoch 6/20
# 233/236 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7667 - loss: 0.7964
# Epoch 6: val_loss improved from 1.03055 to 0.96124, saving model to best_model.keras
#
# Epoch 6: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.7780 - loss: 0.7583 - val_accuracy: 0.7777 - val_loss: 0.9612
# Epoch 7/20
# 233/236 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8227 - loss: 0.6095
# Epoch 7: val_loss improved from 0.96124 to 0.92523, saving model to best_model.keras
#
# Epoch 7: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8244 - loss: 0.6057 - val_accuracy: 0.7916 - val_loss: 0.9252
# Epoch 8/20
# 233/236 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8531 - loss: 0.4976
# Epoch 8: val_loss did not improve from 0.92523
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8599 - loss: 0.4896 - val_accuracy: 0.8006 - val_loss: 0.9302
# Epoch 9/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8819 - loss: 0.4220
# Epoch 9: val_loss improved from 0.92523 to 0.91741, saving model to best_model.keras
#
# Epoch 9: finished saving model to best_model.keras
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - accuracy: 0.8793 - loss: 0.4286 - val_accuracy: 0.8100 - val_loss: 0.9174
# Epoch 10/20
# 233/236 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8995 - loss: 0.3598
# Epoch 10: val_loss did not improve from 0.91741
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8961 - loss: 0.3694 - val_accuracy: 0.8113 - val_loss: 0.9520
# Epoch 11/20
# 233/236 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9124 - loss: 0.3168
# Epoch 11: val_loss did not improve from 0.91741
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9097 - loss: 0.3261 - val_accuracy: 0.8239 - val_loss: 0.9204
# Epoch 12/20
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9242 - loss: 0.2709
# Epoch 12: val_loss did not improve from 0.91741
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9205 - loss: 0.2861 - val_accuracy: 0.8190 - val_loss: 0.9728
# Epoch 12: early stopping
# Restoring model weights from the end of the best epoch: 9.
# Best Val Accuracy: 0.8239

# %% [markdown]
# ## 6: Evaluate on Test Set
#  Test on unseen data to measure real accuracy using classification report.

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {acc:.4f} | Test Loss: {loss:.4f}')

y_pred = np.argmax(model.predict(X_test), axis=1)
print('\nClassification Report (top 10 classes):')
print(classification_report(y_test, y_pred, target_names=le.classes_, labels=np.arange(10)))
# Out:
# Test Accuracy: 0.0087 | Test Loss: 5.0197
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
#
# Classification Report (top 10 classes):
#                            precision    recall  f1-score   support
#
#       accept_reservations       0.00      0.00      0.00        30
#           account_blocked       0.00      0.00      0.00        30
#                     alarm       0.00      0.00      0.00        30
#        application_status       0.00      0.00      0.00        30
#                       apr       0.00      0.00      0.00        30
#             are_you_a_bot       0.00      0.00      0.00        30
#                   balance       0.00      0.00      0.00        30
#              bill_balance       0.00      0.00      0.00        30
#                  bill_due       0.00      0.00      0.00        30
#               book_flight       0.00      0.00      0.00        30
#
#                 micro avg       0.00      0.00      0.00       300
#                 macro avg       0.00      0.00      0.00       300
#              weighted avg       0.00      0.00      0.00       300
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:2687: UserWarning: labels size, 10, does not match size of target_names, 151
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ##  7: Live Inference
# Give new text input, model predicts top 3 most likely intents with confidence %.

# %%
text="what is weather like today"
seq = pad_sequences(tokenizer.texts_to_sequences([text]), maxlen=MAX_LEN, padding='post')
probs=model.predict(seq,verbose=0)[0]
top_idx=probs.argsort()[-3:][::-1]

print("input: ",text)
print("1st:", le.classes_[top_idx[0]], round(probs[top_idx[0]]*100, 1), "%")
print("2nd:", le.classes_[top_idx[1]], round(probs[top_idx[1]]*100, 1), "%")
print("3rd:", le.classes_[top_idx[2]], round(probs[top_idx[2]]*100, 1), "%")
# Out:
# input:  what is weather like today
# 1st: what_is_your_name 0.7 %
# 2nd: do_you_have_pets 0.7 %
# 3rd: ingredient_substitution 0.7 %

# %% [markdown]
# ##  8: Export Model + Artifacts

# %%
# Save model
model.save('intent_model.keras')

# Save tokenizer
import pickle
with open('tokenizer.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# Save label encoder
with open('label_encoder.pkl', 'wb') as f:
    pickle.dump(le, f)

# Download all files to your PC
from google.colab import files
files.download('intent_model.h5')
files.download('tokenizer.pkl')
files.download('label_encoder.pkl')

print("✅ Model exported successfully!")
print("Files saved: intent_model.h5, tokenizer.pkl, label_encoder.pkl")
# Out:
# ✅ Model exported successfully!
# Files saved: intent_model.h5, tokenizer.pkl, label_encoder.pkl
